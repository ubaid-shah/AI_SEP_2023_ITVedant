# %%
import pandas as pd
df=pd.read_csv('starbucks.csv')
df.head()
# Out:
#          Date    Close    Volume
# 0  2015-01-02  38.0061   6906098
# 1  2015-01-05  37.2781  11623796
# 2  2015-01-06  36.9748   7664340
# 3  2015-01-07  37.8848   9732554
# 4  2015-01-08  38.4961  13170548

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006 entries, 0 to 1005
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1006 non-null   object
#  1   Close   1006 non-null   float64
#  2   Volume  1006 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 23.7+ KB

# %%
df=pd.read_csv('starbucks.csv',parse_dates=['Date'])
df.head()
# Out:
#         Date    Close    Volume
# 0 2015-01-02  38.0061   6906098
# 1 2015-01-05  37.2781  11623796
# 2 2015-01-06  36.9748   7664340
# 3 2015-01-07  37.8848   9732554
# 4 2015-01-08  38.4961  13170548

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006 entries, 0 to 1005
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1006 non-null   datetime64[ns]
#  1   Close   1006 non-null   float64
#  2   Volume  1006 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 23.7 KB

# %%
df=pd.read_csv('starbucks.csv',parse_dates=True,index_col='Date')
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df=df.drop(columns='Volume')

# %%
df.head()
# Out:
#               Close
# Date
# 2015-01-02  38.0061
# 2015-01-05  37.2781
# 2015-01-06  36.9748
# 2015-01-07  37.8848
# 2015-01-08  38.4961

# %%
df.Close.plot(figsize=(8,5));

# %%
df['2015'].Close.plot();
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8364\1915301463.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2015'].Close.plot();

# %%
df['2015':'2017'].Close.plot();

# %%
df['2015-03':'2017-03'].Close.plot();

# %%
df['2015-03-15':'2015-03-25'].Close.plot();

# %%
df['2015'].mean()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8364\3441984847.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2015'].mean()
# Close    50.0781
# dtype: float64

# %%
df['2016'].mean()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8364\1381797010.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2016'].mean()
# Close    53.891732
# dtype: float64

# %%
df['2017'].mean()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8364\3550635156.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017'].mean()
# Close    55.45731
# dtype: float64

# %%
df['d1']=df['Close'].diff()

# %%
df.head()
# Out:
#               Close      d1
# Date
# 2015-01-02  38.0061     NaN
# 2015-01-05  37.2781 -0.7280
# 2015-01-06  36.9748 -0.3033
# 2015-01-07  37.8848  0.9100
# 2015-01-08  38.4961  0.6113

# %%
round(df['2015'].d1.mean(),2)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8364\3607540641.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   round(df['2015'].d1.mean(),2)
# 0.07

# %%
round(df['2016'].d1.mean(),2)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8364\232864613.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   round(df['2016'].d1.mean(),2)
# -0.01

# %%
df['d2']=df['d1'].diff()

# %%
df.head()
# Out:
#               Close      d1      d2
# Date
# 2015-01-02  38.0061     NaN     NaN
# 2015-01-05  37.2781 -0.7280     NaN
# 2015-01-06  36.9748 -0.3033  0.4247
# 2015-01-07  37.8848  0.9100  1.2133
# 2015-01-08  38.4961  0.6113 -0.2987

# %%
round(df['2015'].d2.mean(),2)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8364\1499036070.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   round(df['2015'].d2.mean(),2)
# -0.0

# %%
round(df['2016'].d2.mean(),2)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8364\1442865046.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   round(df['2016'].d2.mean(),2)
# -0.0

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
x=seasonal_decompose(df.Close)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 x=seasonal_decompose(df.Close)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py:159, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     157         period = pfreq
#     158     else:
# --> 159         raise ValueError(
#     160             "You must specify a period or x must be a pandas object with "
#     161             "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     162         )
#     163 if x.shape[0] < 2 * pfreq:
#     164     raise ValueError(
#     165         f"x must have 2 complete cycles requires {2 * pfreq} "
#     166         f"observations. x only has {x.shape[0]} observation(s)"
#     167     )
#
# ValueError: You must specify a period or x must be a pandas object with a PeriodIndex or a DatetimeIndex with a freq not set to None

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df.index.freq='D'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py:962, in DatetimeLikeArrayMixin._validate_frequency(cls, index, freq, **kwargs)
#     961     if not np.array_equal(index.asi8, on_freq.asi8):
# --> 962         raise ValueError
#     963 except ValueError as e:
#
# ValueError:
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 df.index.freq='D'
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\extension.py:78, in _inherit_from_data.<locals>.fset(self, value)
#      77 def fset(self, value):
# ---> 78     setattr(self._data, name, value)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py:891, in DatetimeLikeArrayMixin.freq(self, value)
#     889 if value is not None:
#     890     value = to_offset(value)
# --> 891     self._validate_frequency(self, value)
#     893     if self.ndim > 1:
#     894         raise ValueError("Cannot set freq with ndim > 1")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py:973, in DatetimeLikeArrayMixin._validate_frequency(cls, index, freq, **kwargs)
#     967     raise e
#     968 # GH#11587 the main way this is reached is if the `np.array_equal`
#     969 #  check above is False.  This can also be reached if index[0]
#     970 #  is `NaT`, in which case the call to `cls._generate_range` will
#     971 #  raise a ValueError, which we re-raise with a more targeted
#     972 #  message.
# --> 973 raise ValueError(
#     974     f"Inferred frequency {inferred} from passed values "
#     975     f"does not conform to passed frequency {freq.freqstr}"
#     976 ) from e
#
# ValueError: Inferred frequency None from passed values does not conform to passed frequency D

# %%
df=df.asfreq('D')

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-03', '2015-01-04', '2015-01-05',
#                '2015-01-06', '2015-01-07', '2015-01-08', '2015-01-09',
#                '2015-01-10', '2015-01-11',
#                ...
#                '2018-12-22', '2018-12-23', '2018-12-24', '2018-12-25',
#                '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-29',
#                '2018-12-30', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1460, freq='D')

# %%
x=seasonal_decompose(df.Close)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 x=seasonal_decompose(df.Close)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py:146, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     143 nobs = len(x)
#     145 if not np.all(np.isfinite(x)):
# --> 146     raise ValueError("This function does not handle missing values")
#     147 if model.startswith("m"):
#     148     if np.any(x <= 0):
#
# ValueError: This function does not handle missing values

# %%
df.head()
# Out:
#               Close      d1      d2
# Date
# 2015-01-02  38.0061     NaN     NaN
# 2015-01-03      NaN     NaN     NaN
# 2015-01-04      NaN     NaN     NaN
# 2015-01-05  37.2781 -0.7280     NaN
# 2015-01-06  36.9748 -0.3033  0.4247

# %%
df=df.ffill()

# %%
df.head()
# Out:
#               Close      d1      d2
# Date
# 2015-01-02  38.0061     NaN     NaN
# 2015-01-03  38.0061     NaN     NaN
# 2015-01-04  38.0061     NaN     NaN
# 2015-01-05  37.2781 -0.7280     NaN
# 2015-01-06  36.9748 -0.3033  0.4247

# %%
x=seasonal_decompose(df.Close)

# %%
x.plot();

# %%
x=seasonal_decompose(df['2015':'2016'].Close)

# %%
x.plot();

# %%
x.trend.plot();

# %%
x.seasonal.plot();

# %%
x.resid.plot();

# %%
df1=pd.DataFrame(df.Close)

# %%
df1['d1']=df1.Close.diff()

# %%
df1['d2']=df1.d1.diff()

# %%
df1.dropna(inplace=True)

# %%
df1.head()
# Out:
#               Close      d1      d2
# Date
# 2015-01-04  38.0061  0.0000  0.0000
# 2015-01-05  37.2781 -0.7280 -0.7280
# 2015-01-06  36.9748 -0.3033  0.4247
# 2015-01-07  37.8848  0.9100  1.2133
# 2015-01-08  38.4961  0.6113 -0.2987

# %%
x=seasonal_decompose(df1['2015':'2016'].d1)

# %%
x.plot();

# %%
y=seasonal_decompose(df1['2015':'2016'].d2)
y.plot();
